# %% [markdown]
# ### Visualisasi Data
# - 3 tipe visualisasi
# - pie chart
# - simpul cell markdown
# - gunakan Title, xlabel, ylabel

# %%
import pandas as pd
from matplotlib import pyplot as plt


# untuk membaca file csv
df = pd.read_csv('sets.csv')
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  year  theme_id  num_parts
# 0                 0           0  1970       414        471
# 1                 1           1  1978        84         12
# 2                 2           2  1987       199          2
# 3                 3           3  1979       143         12
# 4                 4           4  1979       143         12
# ...             ...         ...   ...       ...        ...
# 11668         11668       11668  2012       408         15
# 11669         11669       11669  2015       598         59
# 11670         11670       11670  2010       408        146
# 11671         11671       11671  2013       494         28
# 11672         11672       11672  1996       476          3
#
# [11673 rows x 5 columns]

# %% [markdown]
# #### Pie Chart

# %%
df = df.dropna(subset=['year'])
pie = df['year'].value_counts().rename_axis('year').reset_index(name='tahun')

plt.figure(figsize=(10,10))
plt.pie(pie.tahun, labels=pie.year, startangle=2, autopct='%.1f%%')
plt.title('year')
plt.show()

# %% [markdown]
# ##### menampilkan rentan perbandingan persentase jumlah part di setiap tahun pada grafik pie

# %% [markdown]
# #### Grafik Plot dan Garis

# %%
plt.plot(df.year, df.num_parts)

# %% [markdown]
# ##### pada grafik diatas menampilkan nomor parts dari tahun 1950 dampai 2020

# %% [markdown]
# #### Grafik Batang

# %%
y = list(df.iloc[:,2])
x = list(df.iloc[:,2])

plt.bar(x, y, color='blue')
plt.title("sets")
plt.xlabel("year")
plt.ylabel("number parts")
# Out:
# Text(0, 0.5, 'number parts')

# %% [markdown]
# ##### menampilkan year dan num_parts  dengan xlabel = year dan ylabel = number parts
